# %%
import numpy as np
import tensorflow as tf
import tensorflow_gnn as tfgnn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\graph\tf_internal.py:35
#      34 try:
# ---> 35   from keras.engine import keras_tensor
#      36 except ImportError:
#      37   # Path as seen in pip packages as of TF/Keras 2.13.
#
# ImportError: cannot import name 'keras_tensor' from 'keras.engine' (c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\keras\engine\__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\benja\OneDrive\Documents\Projects\GNN_example\mutag_example.ipynb Cell 1 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/benja/OneDrive/Documents/Projects/GNN_example/mutag_example.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/benja/OneDrive/Documents/Projects/GNN_example/mutag_example.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> import tensorflow as tf
# ----> <a href='vscode-notebook-cell:/c%3A/Users/benja/OneDrive/Documents/Projects/GNN_example/mutag_example.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import tensorflow_gnn as tfgnn
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\__init__.py:29
#      15 """Public interface for TensorFlow GNN package.
#      16
#      17 All the public symbols, data types and functions are provided from this
#    (...)
#      25 `Field`, and a `GraphTensorSpec` describes an instance of `GraphTensor`.
#      26 """
#      27 # pylint: disable=line-too-long
# ---> 29 from tensorflow_gnn import experimental  # Exposed as submodule. pylint: disable=unused-import
#      30 from tensorflow_gnn import keras  # Exposed as submodule. pylint: disable=unused-import
#      31 from tensorflow_gnn import sampler  # Exposed as submodule. pylint: disable=unused-import
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\experimental\__init__.py:33
#       1 # Copyright 2021 The TensorFlow GNN Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Experimental (unstable) parts of the public interface of TensorFlow GNN.
#      16
#      17 A symbol `foo` exposed here is available to library users as
#    (...)
#      30 That is for special cases only.
#      31 """
# ---> 33 from tensorflow_gnn.graph import readout
#      34 from tensorflow_gnn.graph import tensor_utils
#      36 context_readout_into_feature = readout.context_readout_into_feature
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\graph\readout.py:22
#      18 from typing import Dict, Optional, Sequence, Tuple
#      20 import tensorflow as tf
# ---> 22 from tensorflow_gnn.graph import adjacency as adj
#      23 from tensorflow_gnn.graph import broadcast_ops
#      24 from tensorflow_gnn.graph import graph_constants as const
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\graph\adjacency.py:21
#      19 import tensorflow as tf
#      20 from tensorflow_gnn.graph import graph_constants as const
# ---> 21 from tensorflow_gnn.graph import graph_piece as gp
#      22 from tensorflow_gnn.graph import tensor_utils as utils
#      23 from tensorflow_gnn.graph import tf_internal
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\graph\graph_piece.py:26
#      23 import tensorflow as tf
#      25 from tensorflow_gnn.graph import graph_constants as const
# ---> 26 from tensorflow_gnn.graph import tensor_utils as utils
#      27 from tensorflow_gnn.graph import tf_internal
#      29 ShapeLike = const.ShapeLike
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\graph\tensor_utils.py:20
#      16 from typing import List, Optional, Text, Union, Mapping
#      18 import tensorflow as tf
# ---> 20 from tensorflow_gnn.graph import tf_internal
#      22 Value = Union[tf.Tensor, tf.RaggedTensor]
#      23 ValueSpec = Union[tf.TensorSpec, tf.RaggedTensorSpec]
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow_gnn\graph\tf_internal.py:38
#      35   from keras.engine import keras_tensor
#      36 except ImportError:
#      37   # Path as seen in pip packages as of TF/Keras 2.13.
# ---> 38   from keras.src.engine import keras_tensor  # pytype: disable=import-error
#      39 try:
#      40   from keras.layers import core as core_layers
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\keras\src\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\keras\src\models\__init__.py:18
#       1 # Copyright 2022 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras models API."""
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\keras\src\engine\functional.py:23
#      20 import itertools
#      21 import warnings
# ---> 23 import tensorflow.compat.v2 as tf
#      25 from keras.src import backend
#      26 from keras.src.dtensor import layout_map as layout_map_lib
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow\_api\v2\compat\__init__.py:37
#       3 """Compatibility functions.
#       4
#       5 The `tf.compat` module contains two sets of compatibility functions.
#    (...)
#      32
#      33 """
#      35 import sys as _sys
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:31
#      29 from . import autograph
#      30 from . import bitwise
# ---> 31 from . import compat
#      32 from . import config
#      33 from . import data
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:37
#       3 """Compatibility functions.
#       4
#       5 The `tf.compat` module contains two sets of compatibility functions.
#    (...)
#      32
#      33 """
#      35 import sys as _sys
# ---> 37 from . import v1
#      38 from . import v2
#      39 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# File c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:158
#     156 from tensorflow.python.framework.ops import device
#     157 from tensorflow.python.framework.ops import disable_eager_execution
# --> 158 from tensorflow.python.framework.ops import disable_tensor_equality
#     159 from tensorflow.python.framework.ops import enable_eager_execution
#     160 from tensorflow.python.framework.ops import enable_tensor_equality
#
# ImportError: cannot import name 'disable_tensor_equality' from 'tensorflow.python.framework.ops' (c:\Users\benja\OneDrive\Documents\Projects\GNN_example\.venv\lib\site-packages\tensorflow\python\framework\ops.py)

# %%
# !wget https://storage.googleapis.com/download.tensorflow.org/data/mutag.zip
